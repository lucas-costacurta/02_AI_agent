# %%
from dotenv import load_dotenv
from pydantic import BaseModel
import getpass
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import PydanticOutputParser

load_dotenv()  # Load environment variables from .env file

gemini_key = os.getenv("GEMINI_API_KEY")

llm_gemini = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)  # Initialize Gemini LLM


messages = [
    ("system", "Você é um assistente amigável."),
    ("human", input("Como posso ajudar você hoje? "))
]
ai_msg = llm_gemini.invoke(messages)
print(ai_msg.content)
# Out:
# As limitações ao usar a API gratuita do Gemini (Google AI) dependem do plano "Google AI Studio" e podem mudar com o tempo. No entanto, aqui estão as limitações mais comuns que você pode encontrar:
#
# **Limitações Gerais:**
#
# *   **Uso Limitado:** A API gratuita geralmente tem um limite no número de solicitações que você pode fazer por minuto, dia ou mês. Isso é para evitar abusos e garantir que todos tenham acesso.
# *   **Recursos Limitados:** Alguns recursos avançados ou modelos maiores podem não estar disponíveis no plano gratuito. Você pode ter acesso apenas a modelos menores e mais rápidos.
# *   **Prioridade Mais Baixa:** Usuários pagantes geralmente têm prioridade no acesso aos recursos da API. Isso significa que você pode experimentar tempos de resposta mais lentos ou até mesmo erros de "limite de taxa excedido" com mais frequência durante horários de pico.
# *   **Uso Não Comercial:** A licença gratuita pode proibir o uso da API para fins comerciais diretos. Isso significa que você não pode construir um produto ou serviço que gere receita diretamente usando a API gratuita.
# *   **Marca d'água ou Atribuição:** Em alguns casos, você pode ser obrigado a exibir uma atribuição ou marca d'água informando que o conteúdo foi gerado usando a API do Google AI.
# *   **Termos de Serviço:** É crucial ler e entender os Termos de Serviço da API do Google AI. Eles detalham todas as limitações e restrições de uso, bem como as políticas de conteúdo.
# *   **Disponibilidade Geográfica:** A API pode não estar disponível em todas as regiões geográficas.
#
# **Limitações Específicas (Exemplos):**
#
# *   **Limite de Tokens:** Pode haver um limite no número de tokens (palavras ou partes de palavras) que você pode enviar em uma única solicitação ou receber como resposta.
# *   **Tipos de Solicitação:** Alguns tipos de solicitação, como ajuste fino de modelos ou acesso a dados de treinamento, podem não estar disponíveis no plano gratuito.
# *   **Suporte Técnico:** O suporte técnico para usuários do plano gratuito geralmente é limitado ou inexistente.
#
# **Como Descobrir as Limitações Exatas:**
#
# 1.  **Documentação Oficial:** A fonte mais confiável de informações é a documentação oficial da API do Google AI (Gemini). Procure por seções sobre "limites de taxa", "cotas" ou "termos de serviço".
# 2.  **Painel do Google AI Studio:** Depois de se inscrever no Google AI Studio, você provavelmente terá acesso a um painel onde poderá ver seus limites de uso atuais e outras informações relevantes.
# 3.  **Respostas da API:** A API geralmente retorna mensagens de erro específicas quando você atinge um limite. Preste atenção a essas mensagens para entender o que está acontecendo.
#
# **Dicas:**
#
# *   **Monitore seu uso:** Acompanhe quantas solicitações você está fazendo para evitar exceder os limites.
# *   **Otimize suas solicitações:** Tente enviar solicitações mais concisas e eficientes para reduzir o número de tokens usados.
# *   **Implemente tratamento de erros:** Adicione código ao seu aplicativo para lidar com erros de "limite de taxa excedido" e tentar novamente as solicitações mais tarde.
# *   **Considere um plano pago:** Se você precisar de mais recursos ou uso comercial, avalie a possibilidade de atualizar para um plano pago.
#
# Lembre-se que as informações acima são baseadas no conhecimento geral sobre APIs gratuitas e podem não ser totalmente precisas para o Gemini. Sempre consulte a documentação oficial do Google AI para obter as informações mais atualizadas.

# %%
from dotenv import load_dotenv
from pydantic import BaseModel
import os

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import PydanticOutputParser

load_dotenv()

gemini_key = os.getenv("GEMINI_API_KEY")

llm_gemini = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    temperature=0,
)

# Modelo Pydantic
class ResearchResponse(BaseModel):
    topic: str
    summary: str
    sources: list[str]
    tools_used: list[str]

parser = PydanticOutputParser(
    pydantic_object=ResearchResponse
)

prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        "Você é um assistente de pesquisa especializado em fornecer resumos detalhados."
    ),
    (
        "human",
        "Forneça um resumo detalhado sobre o seguinte tópico:\n\n"
        "{topic}\n\n"
        "{format_instructions}"
    )
]).partial(format_instructions=parser.get_format_instructions())

chain = prompt | llm_gemini | parser

query = input("O que deseja saber? ")
response = chain.invoke({"topic": query})

print(response)
# Out:
# topic='API Functionality Testing' summary='The user is conducting a basic test to verify the functionality of an API. This likely involves sending a simple request to the API and confirming that a response is received. The purpose is to ensure the API is operational and that the user can interact with it.' sources=[] tools_used=[]
